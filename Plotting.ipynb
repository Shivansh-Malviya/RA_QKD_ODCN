# %% [raw]
# * Step 1 : Simulate for the same parameters (numCR, z, k, j_range) for different aslc
# * Step 2 : Obtain the data from the respective files : X_range, Average_SRCR, Average_NSP, and replace them in the below cell
# * Step 3 : Modify the cell 3 based on the number of datasets.

# %%
import matplotlib.pyplot as plt

# %%
X_range = [25.0, 50.0, 75.0, 100.0, 125.0, 150.0, 175.0, 200.0, 225.0, 250.0, 275.0, 300.0, 325.0, 350.0, 375.0, 400.0, 425.0, 450.0, 475.0, 500.0, 525.0, 550.0, 575.0, 600.0, 625.0, 650.0, 675.0, 700.0, 725.0, 750.0, 775.0, 800.0, 825.0 
          ]
num_iter = 100
k = 10

"QKRA-SSL: k = 10, Averaged over(z) = 10 : " 
Average_SRCR_ssl = [1.0, 1.0, 0.9998666666666667, 0.9989999999999998, 0.9928000000000003, 0.9755999999999999, 0.949142857142857, 0.9080000000000001, 0.8627111111111122, 0.8195999999999993, 0.7761454545454542, 0.7378000000000001, 0.7006461538461539, 0.6662285714285716, 0.6342666666666668, 0.6075999999999999, 0.5863764705882354, 0.5640444444444443, 0.5404, 0.51992, 0.5015047619047619, 0.48621818181818177, 0.46914782608695665, 0.4535666666666667, 0.44177600000000017, 0.4289999999999998, 0.4164296296296295, 0.40635714285714264, 0.39369655172413787, 0.38218666666666673, 0.3758064516129032, 0.36426249999999993, 0.3562666666666667 
] 

Average_TUR_ssl = [0.08942857142857129, 0.18058730158730132, 0.2678253968253969, 0.3580634920634919, 0.45161904761904714, 0.5341746031746039, 0.6036984126984128, 0.664730158730159, 0.7076349206349206, 0.7413174603174602, 0.7674285714285713, 0.7836825396825396, 0.8028888888888887, 0.8132222222222224, 0.8248412698412697, 0.835460317460317, 0.8470952380952381, 0.8546825396825394, 0.8636507936507932, 0.8713492063492061, 0.8761428571428566, 0.8879523809523807, 0.8878571428571428, 0.8927460317460313, 0.9006190476190471, 0.9057936507936502, 0.9108253968253963, 0.9132380952380946, 0.918380952380952, 0.9211746031746025, 0.9259047619047611, 0.9284920634920634, 0.9318888888888884 
] 

Average_NSP_ssl = [100.0, 200.13, 299.95, 399.41, 495.64, 582.27, 657.26, 715.12, 761.2, 801.64, 833.49, 864.13, 888.37, 910.91, 927.17, 947.46, 972.78, 988.78, 1000.68, 1011.74, 1025.17, 1040.15, 1051.19, 1059.08, 1074.04, 1085.9, 1094.66, 1107.02, 1109.83, 1115.28, 1131.83, 1132.48, 1142.12
]


"QKRA-AWSL: k = 10, Averaged over(z) = 10 : "
Average_SRCR_awsl = [1.0, 1.0, 1.0, 1.0, 0.9988800000000001, 0.9914666666666669, 0.9643999999999996, 0.9167000000000003, 0.8664444444444441, 0.82512, 0.7702909090909092, 0.7294000000000003, 0.6940307692307696, 0.6609142857142857, 0.6276266666666666, 0.59955, 0.5693176470588237, 0.5431333333333334, 0.5214105263157894, 0.5011800000000002, 0.4817333333333331, 0.46221818181818203, 0.447913043478261, 0.43323333333333325, 0.41963200000000006, 0.40832307692307696, 0.39557037037037035, 0.38470000000000004, 0.3738482758620688, 0.36377333333333334, 0.3542709677419357, 0.3462875000000001, 0.33629090909090914 


# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (12, 6))

scatter = 0
line = 1

# Scatter plots
if scatter == True:
    # ax 1 for SRCR
    ax1.scatter(X_range, Average_SRCR_ssl, label='SRCR - SSL') 
    ax1.scatter(X_range, Average_SRCR_assl, label='SRCR - ASSL') 
    ax1.scatter(X_range, Average_SRCR_awsl, label='SRCR - AWSL') 
    
    # ax2 for TUR
    ax2.scatter(X_range, Average_TUR_ssl, label='TUR - SSL') 
    ax2.scatter(X_range, Average_TUR_assl, label='TUR - ASSL') 
    ax2.scatter(X_range, Average_TUR_awsl, label='TUR - AWSL') 
    
    # ax3 for NSP
    ax3.scatter(X_range, Average_NSP_ssl, label='NSP - SSL') 
    ax3.scatter(X_range, Average_NSP_assl, label='NSP - ASSL') 
    ax3.scatter(X_range, Average_NSP_awsl, label='NSP - AWSL') 

# Line plots
if line == True:
    ax1.plot(X_range, Average_SRCR_ssl, label='SRCR - SSL') 
    ax1.plot(X_range, Average_SRCR_assl, label='SRCR - ASSL') 
    ax1.plot(X_range, Average_SRCR_awsl, label='SRCR - AWSL') 
    
    ax2.plot(X_range, Average_TUR_ssl, label='TUR - SSL') 
    ax2.plot(X_range, Average_TUR_assl, label='TUR - ASSL') 
    ax2.plot(X_range, Average_TUR_awsl, label='TUR - AWSL') 
    
    ax3.plot(X_range, Average_NSP_ssl, label='NSP - SSL') 
    ax3.plot(X_range, Average_NSP_assl, label='NSP - ASSL') 
    ax3.plot(X_range, Average_NSP_awsl, label='NSP - AWSL') 


ax1.set_xlabel('X = Number of CRs')
ax1.set_ylabel('SRCR')
ax1.set_title("SRCR v/s X")
ax1.minorticks_on()
ax1.legend(loc='best')

ax2.set_xlabel('X = Number of CRs')
ax2.set_ylabel('TUR')
ax2.set_title("TUR v/s X")
ax2.minorticks_on()
ax2.legend(loc='best')

ax3.set_xlabel('X = Number of CRs')
ax3.set_ylabel('NSP')
ax3.set_title("NSP v/s X")
ax3.minorticks_on()
ax3.legend(loc='best')

fig.suptitle(f"Network Evaluation for QKRA : averaged over {num_iter} iterations, k = {k}", y=1.05)  # Place title above subplots
#fig.legend(loc='best')

# Show the plot
plt.tight_layout()  # Adjust spacing between subplots
plt.show()


# Saving the plot
filename = (f"Comparision - z = {num_iter}, k = {k} for X - {str(X_range[0])} to {str(X_range[-1])}.jpeg")
print(filename)

# Combine the subdirectory and filename to create the full path
#fig_path = os.path.join(fig_subdirectory, filename)
#plt.savefig(fig_path, dpi=300, bbox_inches='tight')
# Out:
# Comparision - z = 100, k = 10 for X - 25.0 to 825.0.jpeg
