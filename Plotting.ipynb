# %% [raw]
# * Step 1 : Simulate for the same parameters (numCR, z, k, j_range) for different aslc
# * Step 2 : Obtain the data from the respective files : X_range, Average_SRCR, Average_NSP, and replace them in the below cell
# * Step 3 : Modify the cell 3 based on the number of datasets.

# %%
import matplotlib.pyplot as plt

# %%
X_range = [25.0, 50.0, 75.0, 100.0, 125.0, 150.0, 175.0, 200.0, 225.0, 250.0, 275.0, 300.0, 325.0, 350.0, 375.0, 400.0, 425.0, 450.0, 475.0, 500.0, 525.0, 550.0, 575.0, 600.0, 625.0, 650.0, 675.0, 700.0, 725.0, 750.0, 775.0, 800.0, 825.0]
num_iter = 10
k = 10

"QKRA-SSL: k = 10, Averaged over(z) = 10 : " 
Average_SRCR_ssl = [1.0, 1.0, 1.0, 1.0, 0.9936, 0.9793333333333333, 0.9451428571428571, 0.9105000000000001, 0.8595555555555556, 0.8252, 0.7618181818181818, 0.7293333333333333, 0.7033846153846153, 0.6714285714285715, 0.6248, 0.609, 0.588235294117647, 0.5664444444444444, 0.5429473684210526, 0.5234, 0.49714285714285716, 0.48599999999999993, 0.4669565217391304, 0.4615, 0.45056, 0.42400000000000004, 0.4207407407407408, 0.4035714285714286, 0.39117241379310347, 0.38079999999999997, 0.3696774193548387, 0.36287499999999995, 0.3566060606060606 
] 

Average_TUR_ssl = [0.0892063492063492, 0.18873015873015872, 0.2666666666666666, 0.3612698412698413, 0.45285714285714285, 0.5395238095238095, 0.6011111111111112, 0.6734920634920636, 0.7052380952380953, 0.7412698412698413, 0.7523809523809524, 0.7774603174603174, 0.806031746031746, 0.8101587301587301, 0.8279365079365079, 0.84015873015873, 0.8428571428571427, 0.853174603174603, 0.8690476190476192, 0.8676190476190477, 0.8739682539682541, 0.8750793650793651, 0.8906349206349209, 0.8965079365079367, 0.9053968253968255, 0.9015873015873017, 0.9065079365079367, 0.9120634920634922, 0.9200000000000002, 0.9192063492063494, 0.9185714285714287, 0.9261904761904762, 0.9328571428571429 
] 

Average_NSP_ssl = [100.2, 199.6, 300.0, 399.6, 496.0, 584.5, 654.0, 717.3, 759.5, 809.7, 821.0, 855.4, 890.7, 921.7, 915.5, 952.9, 978.6, 993.0, 1003.0, 1017.1, 1014.2, 1041.6, 1044.6, 1076.9, 1096.6, 1072.7, 1105.8, 1101.7, 1101.8, 1108.9, 1119.1, 1131.4, 1143.5
]


"QKRA-AWSL: k = 10, Averaged over(z) = 10 : "
Average_SRCR_awsl = [1.0, 1.0, 1.0, 1.0, 0.9992000000000001, 0.992, 0.9617142857142857, 0.9179999999999999, 0.8844444444444447, 0.8144, 0.7654545454545454, 0.7266666666666667, 0.700923076923077, 0.6385714285714286, 0.6264000000000001, 0.5952500000000001, 0.5625882352941177, 0.5402222222222222, 0.5181052631578947, 0.4952, 0.47352380952380957, 0.4616363636363636, 0.4528695652173913, 0.4375, 0.42160000000000003, 0.4029230769230769, 0.3897777777777777, 0.38500000000000006, 0.37503448275862067, 0.36373333333333335, 0.352258064516129, 0.34662499999999996, 0.3423030303030303 


# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (12, 6))

# ax1 for SRCR
ax1.scatter(X_range, Average_SRCR_ssl, label='SRCR - SSL') 
ax1.scatter(X_range, Average_SRCR_assl, label='SRCR - ASSL') 
ax1.scatter(X_range, Average_SRCR_awsl, label='SRCR - AWSL') 

ax1.plot(X_range, Average_SRCR_ssl, label='SRCR - SSL') 
ax1.plot(X_range, Average_SRCR_assl, label='SRCR - ASSL') 
ax1.plot(X_range, Average_SRCR_awsl, label='SRCR - AWSL') 


# ax2 for TUR
ax2.scatter(X_range, Average_TUR_ssl, label='TUR - SSL') 
ax2.scatter(X_range, Average_TUR_assl, label='TUR - ASSL') 
ax2.scatter(X_range, Average_TUR_awsl, label='TUR - AWSL') 

ax2.plot(X_range, Average_TUR_ssl, label='TUR - SSL') 
ax2.plot(X_range, Average_TUR_assl, label='TUR - ASSL') 
ax2.plot(X_range, Average_TUR_awsl, label='TUR - AWSL') 


# ax3 for NSP
ax3.scatter(X_range, Average_NSP_ssl, label='NSP - SSL') 
ax3.scatter(X_range, Average_NSP_assl, label='NSP - ASSL') 
ax3.scatter(X_range, Average_NSP_awsl, label='NSP - AWSL') 

ax3.plot(X_range, Average_NSP_ssl, label='NSP - SSL') 
ax3.plot(X_range, Average_NSP_assl, label='NSP - ASSL') 
ax3.plot(X_range, Average_NSP_awsl, label='NSP - AWSL') 


ax1.set_xlabel('X = Number of CRs')
ax1.set_ylabel('SRCR')
ax1.set_title("SRCR v/s X")
ax1.minorticks_on()
ax1.legend(loc='best')

ax2.set_xlabel('X = Number of CRs')
ax2.set_ylabel('TUR')
ax2.set_title("TUR v/s X")
ax2.minorticks_on()
ax2.legend(loc='best')

ax3.set_xlabel('X = Number of CRs')
ax3.set_ylabel('NSP')
ax3.set_title("NSP v/s X")
ax3.minorticks_on()
ax3.legend(loc='best')

fig.suptitle(f"Network Evaluation for QKRA : averaged over {num_iter} iterations, k = {k}", y=1.05)  # Place title above subplots
#fig.legend(loc='best')

# Show the plot
plt.tight_layout()  # Adjust spacing between subplots
plt.show()


# Saving the plot
filename = (f"Comparision - z = {num_iter}, k = {k} for X - {str(X_range[0])} to {str(X_range[-1])}.jpeg")
print(filename)

# Combine the subdirectory and filename to create the full path
#fig_path = os.path.join(fig_subdirectory, filename)
#plt.savefig(fig_path, dpi=300, bbox_inches='tight')
# Out:
# Comparision - z = 10, k = 10 for X - 25.0 to 825.0.jpeg
